# %% [markdown]
# ### 기본 세팅

# %%
import numpy as np
import pandas as pd
import pickle

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.model_selection import KFold

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 임베딩 배열을 데이터프레임으로 변환
def make_df(data):

    array = data[0]     # 첫번째 array
    error = []          # 에러 인덱스 리스트


    for index in range(len(data)-1):
        plus_array = data[index+1]     # 추가할 array
        try:
            array = np.concatenate((array, plus_array), axis=0)
        except:
            print(index+1, '번 인덱스 오류 처리 완료')
            error.append(index+1)     # 에러 인덱스 저장

        # 201건부터는 모두 보이스피싱 텍스트 임베딩값
        # 보이스피싱 여부를 붙이고자 phishing_check로 인덱스 지정
        if (index+1) == 199:
            phishing_check = array.shape[0] + 1


    # 데이터프레임 변환 및 레이블 지정
    df = pd.DataFrame(array)
    df['phishing'] = 0                        # 상담 텍스트 임베딩값
    df.loc[phishing_check:,'phishing'] = 1    # 보이스파싱 텍스트 임베딩값
    return df

# %% [markdown]
# ### train, validation 분할

# %%
def data_split(df):
    feature = df.iloc[:,:-1]      # 피처 칼럼: 예측에 사용되는 데이터
    target  = df['phishing']      # 타겟 칼럼: 예측(분류) 대상 데이터
    x_train, x_valid, y_train, y_valid = train_test_split(feature, target, test_size=0.2,
                                                          shuffle=True,
                                                          stratify=target,
                                                          random_state=1234)
    return x_train, x_valid, y_train, y_valid, feature, target

# %% [markdown]
# ### 분류 모델 세팅

# %%
# 분류 score 계산
def score(pred, y_test):
    print(' accuracy  : ', accuracy_score(y_test, pred))
    print(' f1-score  : ', f1_score(y_test, pred))
    print(' recall    : ', recall_score(y_test, pred))
    print(' precision : ', precision_score(y_test, pred))
    return accuracy_score(y_test, pred), f1_score(y_test, pred), recall_score(y_test, pred), precision_score(y_test, pred)

# %%
# score result에 결과 추가
def result_append(score_result, scores):
    score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)
    return score_result

# %%
# 최종 결과 리스트
score_result = pd.DataFrame(columns=['logistic_Acc', 'logistic_F1', 'logistic_Rec', 'logistic_Pre',
                                     'naivebayes_Acc', 'naivebayes_F1', 'naivebayes_Rec', 'naivebayes_Pre',
                                     'randomforest_Acc', 'logistic_F1', 'naivebayes_Rec', 'randomforest_Pre',
                                     'logistic_5fold_Acc', 'logistic_5fold_F1', 'logistic_5fold_Rec', 'logistic_5fold_Pre',
                                     'naivebayes_5Fold_Acc', 'naivebayes_5Fold_F1', 'naivebayes_5Fold_Rec', 'naivebayes_5Fold_Pre',
                                     'randomforest_5Fold_Acc', 'randomforest_5Fold_F1', 'randomforest_5Fold_Rec', 'randomforest_5Fold_Pre'])

# %% [markdown]
# ### Logistic Regression

# %%
def logistic_reg(x_train, y_train, x_valid, y_valid):

    # 모델 분류 수행
    reg = LogisticRegression(random_state=0, max_iter=500)
    reg.fit(x_train, y_train)
    pred = reg.predict(x_valid)


    # 분류 score 계산
    accuracy, f1_score, recall, precision = score(pred, y_valid)
    return accuracy, f1_score, recall, precision

# %% [markdown]
# ### Naive Bayes Classification

# %%
def naivebayes_clf(x_train, y_train, x_valid, y_valid):

    # 모델 분류 수행
    gnb = GaussianNB()
    gnb.fit(x_train, y_train)
    pred = gnb.predict(x_valid)


    # 분류 score 계산
    accuracy, f1_score, recall, precision = score(pred, y_valid)
    return accuracy, f1_score, recall, precision

# %% [markdown]
# ### RandomForest Classification

# %%
def randomforest_clf(x_train, y_train, x_valid, y_valid):

    # 모델 분류 수행
    clf = RandomForestClassifier(max_depth=16, random_state=0)
    clf.fit(x_train, y_train)
    pred = clf.predict(x_valid)


    # 분류 score 계산
    accuracy, f1_score, recall, precision = score(pred, y_valid)
    return accuracy, f1_score, recall, precision

# %% [markdown]
# ### K-Fold Cross Validation

# %%
def kfold_clf(model, feature, target):

    # 5개 폴드세트를 분리하는 kFold 객체와
    # 폴드세트별 score 값을 담을 리스트
    kfold = KFold(n_splits=5, random_state=0, shuffle=True)
    cv_accuracy = []
    cv_f1score = []
    cv_precision = []
    cv_recall = []


    n_iter = 0
    for train_index, validate_index in kfold.split(feature):
        # 데이터셋 지정
        X_train, X_valid = feature.iloc[train_index,:], feature.iloc[validate_index,:]
        y_train, y_valid = target[train_index], target[validate_index]


        # 학습 및 예측
        model.fit(X_train, y_train)
        pred = model.predict(X_valid)
        n_iter += 1


        # 데이터 size 확인
        train_size = X_train.shape[0]
        test_size = X_valid.shape[0]
        print(f' ========= {n_iter} =========')


        # iteration마다 score 측정
        accuracy,f1score,precision, recall = score(pred, y_valid)


        # iteration 별 score 값 저장
        cv_accuracy.append(accuracy)
        cv_f1score.append(f1score)
        cv_precision.append(precision)
        cv_recall.append(recall)


    # 개별 iteration별 정확도를 합한 평균 계산
    print(' ======== 최종 ========')
    print(' 평균검증 정확도   : ', np.mean(cv_accuracy))
    print(' 평균검증 f1-score : ', np.mean(cv_f1score))
    print(' 평균검증 정밀도   : ', np.mean(cv_precision))
    print(' 평균검증 재현율   : ', np.mean(cv_recall))
    print(' \n')
    return np.mean(cv_accuracy), np.mean(cv_f1score), np.mean(cv_precision), np.mean(cv_recall)

# %% [markdown]
# ### 전체 분류 모델 통합

# %%
def total_model(data):

    # 임베딩 배열을 데이터프레임으로 전환
    df = make_df(data)
    # train / test 데이터 분할
    x_train, x_valid, y_train, y_valid, feature, target = data_split(df)
    # 리턴할 점수 리스트
    score_list = []
    print(' 데이터 가공 완료\n')


    # Logistic Regression
    print('      ----------    Logistic Regression Result    ----------      ')
    logi1, logi2, logi3, logi4 = logistic_reg(x_train, y_train, x_valid, y_valid)
    score_list += [logi1, logi2, logi3, logi4]


    # Naive Bayes Classification
    print('      ---------- Naive Bayes Classification Result ----------      ')
    naive1, naive2, naive3, naive4 = naivebayes_clf(x_train, y_train, x_valid, y_valid)
    score_list += [naive1, naive2, naive3, naive4]


    # RandomForest Classification
    print('      ---------- RandomForest Classifcation Result ----------      ')
    rf1, rf2, rf3, rf4 = randomforest_clf(x_train, y_train, x_valid, y_valid)
    score_list += [rf1, rf2, rf3, rf4]


    # 5-Fold Logistic Regression
    print(' \n')
    print('   ----------    [5-Fold] Logistic Regression Result    ----------   ')
    lgb = LogisticRegression(random_state=0, max_iter=500)
    foldlogi1, foldlogi2, foldlogi3, foldlogi4 = kfold_clf(lgb, feature, target)
    score_list += [foldlogi1, foldlogi2, foldlogi3, foldlogi4]


    # 5-Fold NaiveBayes
    print('   ---------- [5-Fold] Naive Bayes Classification Result ----------   ')
    gnb = GaussianNB()
    foldnb1, foldnb2, foldnb3, foldnb4 = kfold_clf(gnb, feature, target)
    score_list += [foldnb1, foldnb2, foldnb3, foldnb4]


    # 5-Fold RandomForest Classification
    print('   ---------- [5-Fold] RandomForest Classifcation Result ----------   ')
    clf = RandomForestClassifier(max_depth=16, random_state=0)
    foldrf1, foldrf2, foldrf3, foldrf4 = kfold_clf(clf, feature, target)
    score_list += [foldrf1, foldrf2, foldrf3, foldrf4]
    return score_list

# %% [markdown]
# ### 모델 이용 데이터셋 분류: original

# %%
# 데이터 로드
origin_2gram = np.load('./path/original_2gram_embedding.npy', allow_pickle=True)
origin_3gram = np.load('./path/original_3gram_embedding.npy', allow_pickle=True)
origin_4gram = np.load('./path/original_4gram_embedding.npy', allow_pickle=True)

# %%
# original_2gram
ori_2g = total_model(origin_2gram)
score_result = result_append(score_result, ori_2g)
# Out:
# 104 번 인덱스 오류 처리 완료
# 130 번 인덱스 오류 처리 완료
# 132 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.8026895432413633
#  f1-score  :  0.7186776859504133
#  recall    :  0.7160737812911726
#  precision :  0.721300597213006
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.6760955251565036
#  f1-score  :  0.6190346332151624
#  recall    :  0.7476943346508564
#  precision :  0.5281526291298279
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.7651286807326687
#  f1-score  :  0.6243974786800148
#  recall    :  0.5546772068511199
#  precision :  0.714164546225615
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.790864827266404
#  f1-score  :  0.7050359712230215
#  recall    :  0.7050359712230215
#  precision :  0.7050359712230215
#  ========= 2 =========
#  accuracy  :  0.8080222582888941
#  f1-score  :  0.7288801571709234
#  recall    :  0.7395348837209302
#  precision :  0.7185280826339574
#  ========= 3 =========
#  accuracy  :  0.8052399721771388
#  f1-score  :  0.7292069632495165
#  recall    :  0.746042216358839
#  precision :  0.7131147540983607
#  ========= 4 =========
#  accuracy  :  0.8066311152330164
#  f1-score  :  0.7302716688227684
#  recall    :  0.7461996034368804
#  precision :  0.7150094996833439
#  ========= 5 =========
#  accuracy  :  0.8036169719452817
#  f1-score  :  0.7232930414897093
#  recall    :  0.7259016393442623
#  precision :  0.720703125
#  ======== 최종 ========
#  평균검증 정확도   :  0.8028750289821469
#  평균검증 f1-score :  0.7233375603911878
#  평균검증 정밀도   :  0.7325428628167867
#  평균검증 재현율   :  0.7144782865277367
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.6675168096452585
#  f1-score  :  0.6109603906673902
#  recall    :  0.736429038587312
#  precision :  0.5220213259156236
#  ========= 2 =========
#  accuracy  :  0.6744725249246464
#  f1-score  :  0.6076020122973728
#  recall    :  0.7222591362126246
#  precision :  0.5243608297153883
#  ========= 3 =========
#  accuracy  :  0.6809645258520751
#  f1-score  :  0.6209366391184572
#  recall    :  0.7434036939313984
#  precision :  0.5331125827814569
#  ========= 4 =========
#  accuracy  :  0.6795733827961975
#  f1-score  :  0.6234332425068121
#  recall    :  0.7561136814276272
#  precision :  0.5303662494204914
#  ========= 5 =========
#  accuracy  :  0.6830512404358915
#  f1-score  :  0.6284316390323458
#  recall    :  0.7580327868852459
#  precision :  0.5366759517177344
#  ======== 최종 ========
#  평균검증 정확도   :  0.6771156967308138
#  평균검증 f1-score :  0.6182727847244756
#  평균검증 정밀도   :  0.7432476674088416
#  평균검증 재현율   :  0.5293073879101389
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.7653605379086482
#  f1-score  :  0.6287600880410859
#  recall    :  0.5604970568999346
#  precision :  0.7159565580618212
#  ========= 2 =========
#  accuracy  :  0.7623463946209135
#  f1-score  :  0.6207917129115798
#  recall    :  0.5574750830564784
#  precision :  0.7003338898163606
#  ========= 3 =========
#  accuracy  :  0.7755622536517506
#  f1-score  :  0.6420118343195267
#  recall    :  0.5725593667546174
#  precision :  0.7306397306397306
#  ========= 4 =========
#  accuracy  :  0.7776489682355668
#  f1-score  :  0.6498722161372764
#  recall    :  0.5882352941176471
#  precision :  0.7259380097879282
#  ========= 5 =========
#  accuracy  :  0.7739392534198933
#  f1-score  :  0.6460980036297641
#  recall    :  0.5836065573770491
#  precision :  0.7235772357723578
#  ======== 최종 ========
#  평균검증 정확도   :  0.7709714815673545
#  평균검증 f1-score :  0.6375067710078465
#  평균검증 정밀도   :  0.5724746716411453
#  평균검증 재현율   :  0.7192890848156397
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# original_3gram
ori_3g = total_model(origin_3gram)
score_result = result_append(score_result, ori_3g)
# Out:
# 64 번 인덱스 오류 처리 완료
# 104 번 인덱스 오류 처리 완료
# 116 번 인덱스 오류 처리 완료
# 130 번 인덱스 오류 처리 완료
# 132 번 인덱스 오류 처리 완료
# 134 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.83843617522374
#  f1-score  :  0.7792792792792793
#  recall    :  0.812751677852349
#  precision :  0.7484548825710754
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7105511069241639
#  f1-score  :  0.6525303929884083
#  recall    :  0.774496644295302
#  precision :  0.563751831949194
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.796514366462553
#  f1-score  :  0.6914285714285714
#  recall    :  0.6496644295302013
#  precision :  0.7389312977099237
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.8280734809232219
#  f1-score  :  0.7533783783783783
#  recall    :  0.7652711050102952
#  precision :  0.7418496340652029
#  ========= 2 =========
#  accuracy  :  0.8228921337729628
#  f1-score  :  0.758974358974359
#  recall    :  0.7779237844940867
#  precision :  0.7409261576971214
#  ========= 3 =========
#  accuracy  :  0.830153121319199
#  f1-score  :  0.7676442152755397
#  recall    :  0.7897877984084881
#  precision :  0.7467084639498432
#  ========= 4 =========
#  accuracy  :  0.8332155477031802
#  f1-score  :  0.7678688524590163
#  recall    :  0.7965986394557824
#  precision :  0.7411392405063291
#  ========= 5 =========
#  accuracy  :  0.8351001177856302
#  f1-score  :  0.7675962815405046
#  recall    :  0.7758389261744967
#  precision :  0.759526938239159
#  ======== 최종 ========
#  평균검증 정확도   :  0.8298868803008388
#  평균검증 f1-score :  0.7630924173255597
#  평균검증 정밀도   :  0.7810840507086299
#  평균검증 재현율   :  0.7460300868915312
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7025435704192181
#  f1-score  :  0.6346543245588662
#  recall    :  0.7529169526424159
#  precision :  0.5485
#  ========= 2 =========
#  accuracy  :  0.7077249175694772
#  f1-score  :  0.656327887011908
#  recall    :  0.778580814717477
#  precision :  0.5672570607946386
#  ========= 3 =========
#  accuracy  :  0.7055359246171967
#  f1-score  :  0.656781987918726
#  recall    :  0.7931034482758621
#  precision :  0.5604498594189316
#  ========= 4 =========
#  accuracy  :  0.7187279151943463
#  f1-score  :  0.6527050610820244
#  recall    :  0.763265306122449
#  precision :  0.5701219512195121
#  ========= 5 =========
#  accuracy  :  0.703886925795053
#  f1-score  :  0.6423897581792318
#  recall    :  0.7577181208053692
#  precision :  0.5575308641975308
#  ======== 최종 ========
#  평균검증 정확도   :  0.7076838507190583
#  평균검증 f1-score :  0.6485718037501513
#  평균검증 정밀도   :  0.7691169285127145
#  평균검증 재현율   :  0.5607719471261225
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.7962788506829958
#  f1-score  :  0.6787968808020794
#  recall    :  0.6273164035689773
#  precision :  0.7394822006472492
#  ========= 2 =========
#  accuracy  :  0.7932171455487518
#  f1-score  :  0.6908450704225352
#  recall    :  0.6445466491458607
#  precision :  0.7443095599393019
#  ========= 3 =========
#  accuracy  :  0.8004711425206125
#  f1-score  :  0.7016555125044031
#  recall    :  0.6604774535809018
#  precision :  0.7483095416979715
#  ========= 4 =========
#  accuracy  :  0.8021201413427562
#  f1-score  :  0.6945454545454545
#  recall    :  0.6496598639455783
#  precision :  0.74609375
#  ========= 5 =========
#  accuracy  :  0.7926972909305064
#  f1-score  :  0.6816208393632417
#  recall    :  0.6322147651006711
#  precision :  0.7394034536891679
#  ======== 최종 ========
#  평균검증 정확도   :  0.7969569142051245
#  평균검증 f1-score :  0.6894927515275427
#  평균검증 정밀도   :  0.6428430270683979
#  평균검증 재현율   :  0.7435197011947381
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# original_4gram
ori_4g = total_model(origin_4gram)
score_result = result_append(score_result, ori_4g)
# Out:
# 64 번 인덱스 오류 처리 완료
# 91 번 인덱스 오류 처리 완료
# 104 번 인덱스 오류 처리 완료
# 116 번 인덱스 오류 처리 완료
# 130 번 인덱스 오류 처리 완료
# 131 번 인덱스 오류 처리 완료
# 132 번 인덱스 오류 처리 완료
# 134 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.8454175640105288
#  f1-score  :  0.7827841291190317
#  recall    :  0.7967145790554415
#  precision :  0.7693324520819563
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7202680067001676
#  f1-score  :  0.6596797671033477
#  recall    :  0.7754962354551677
#  precision :  0.5739614994934144
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8224455611390284
#  f1-score  :  0.7309644670050761
#  recall    :  0.6899383983572895
#  precision :  0.7771781033153431
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.8492462311557789
#  f1-score  :  0.783356258596974
#  recall    :  0.8021126760563381
#  precision :  0.7654569892473119
#  ========= 2 =========
#  accuracy  :  0.8415888968652788
#  f1-score  :  0.7857605177993527
#  recall    :  0.8153122901276024
#  precision :  0.7582760774515928
#  ========= 3 =========
#  accuracy  :  0.8480134035423648
#  f1-score  :  0.7891066090999668
#  recall    :  0.8092643051771117
#  precision :  0.7699287103046014
#  ========= 4 =========
#  accuracy  :  0.8528003829583533
#  f1-score  :  0.795477219820419
#  recall    :  0.8147138964577657
#  precision :  0.7771280051981806
#  ========= 5 =========
#  accuracy  :  0.8482527525131642
#  f1-score  :  0.7873910127431254
#  recall    :  0.8035592060232717
#  precision :  0.7718606180144642
#  ======== 최종 ========
#  평균검증 정확도   :  0.847980333406988
#  평균검증 f1-score :  0.7882183236119674
#  평균검증 정밀도   :  0.808992474768418
#  평균검증 재현율   :  0.7685300800432302
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7410863843024647
#  f1-score  :  0.6775923718712754
#  recall    :  0.8007042253521127
#  precision :  0.5872933884297521
#  ========= 2 =========
#  accuracy  :  0.7272074659009332
#  f1-score  :  0.6739130434782609
#  recall    :  0.791134989926125
#  precision :  0.5869456900847035
#  ========= 3 =========
#  accuracy  :  0.7180469123982767
#  f1-score  :  0.6612995974698102
#  recall    :  0.7833787465940054
#  precision :  0.572139303482587
#  ========= 4 =========
#  accuracy  :  0.7391096218286262
#  f1-score  :  0.6790341578327445
#  recall    :  0.7854223433242506
#  precision :  0.5980290456431535
#  ========= 5 =========
#  accuracy  :  0.7307324078506462
#  f1-score  :  0.6699911997653271
#  recall    :  0.7816563997262149
#  precision :  0.5862422997946611
#  ======== 최종 ========
#  평균검증 정확도   :  0.7312365584561894
#  평균검증 f1-score :  0.6723660740834836
#  평균검증 정밀도   :  0.7884593409845417
#  평균검증 재현율   :  0.5861299454869714
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8334529791816224
#  f1-score  :  0.7461706783369804
#  recall    :  0.7204225352112676
#  precision :  0.7738275340393344
#  ========= 2 =========
#  accuracy  :  0.8217276860492941
#  f1-score  :  0.7388713634770416
#  recall    :  0.7078576225654802
#  precision :  0.7727272727272727
#  ========= 3 =========
#  accuracy  :  0.8123504068932503
#  f1-score  :  0.7223796033994334
#  recall    :  0.6948228882833788
#  precision :  0.7522123893805309
#  ========= 4 =========
#  accuracy  :  0.8341311632359981
#  f1-score  :  0.7520572450805009
#  recall    :  0.7159400544959128
#  precision :  0.7920120572720422
#  ========= 5 =========
#  accuracy  :  0.824557204404021
#  f1-score  :  0.7333575845762096
#  recall    :  0.6899383983572895
#  precision :  0.782608695652174
#  ======== 최종 ========
#  평균검증 정확도   :  0.8252438879528373
#  평균검증 f1-score :  0.7385672949740332
#  평균검증 정밀도   :  0.7057962997826659
#  평균검증 재현율   :  0.7746775898142708
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# 나온 결과 확인
score_result
# Out:
#    logistic_Acc  logistic_F1  logistic_Rec  logistic_Pre  naivebayes_Acc  \
# 0      0.802690     0.718678      0.716074      0.721301        0.676096
# 1      0.838436     0.779279      0.812752      0.748455        0.710551
# 2      0.845418     0.782784      0.796715      0.769332        0.720268
#
#    naivebayes_F1  naivebayes_Rec  naivebayes_Pre  randomforest_Acc  \
# 0       0.619035        0.747694        0.528153          0.765129
# 1       0.652530        0.774497        0.563752          0.796514
# 2       0.659680        0.775496        0.573961          0.822446
#
#    logistic_F1  ...  logistic_5fold_Rec  logistic_5fold_Pre  \
# 0     0.624397  ...            0.732543            0.714478
# 1     0.691429  ...            0.781084            0.746030
# 2     0.730964  ...            0.808992            0.768530
#
#    naivebayes_5Fold_Acc  naivebayes_5Fold_F1  naivebayes_5Fold_Rec  \
# 0              0.677116             0.618273              0.743248
# 1              0.707684             0.648572              0.769117
# 2              0.731237             0.672366              0.788459
#
#    naivebayes_5Fold_Pre  randomforest_5Fold_Acc  randomforest_5Fold_F1  \
# 0              0.529307                0.770971               0.637507
# 1              0.560772                0.796957               0.689493
# 2              0.586130                0.825244               0.738567
#
#    randomforest_5Fold_Rec  randomforest_5Fold_Pre
# 0                0.572475                0.719289
# 1                0.642843                0.743520
# 2                0.705796                0.774678
#
# [3 rows x 24 columns]

# %% [markdown]
# ### 모델 이용 데이터셋 분류: eng

# %%
# 데이터 로드
eng_ratio5_2gram = np.load('./path/eng_ratio5_2gram_embedding.npy', allow_pickle=True)
eng_ratio5_3gram = np.load('./path/eng_ratio5_3gram_embedding.npy', allow_pickle=True)
eng_ratio5_4gram = np.load('./path/eng_ratio5_4gram_embedding.npy', allow_pickle=True)

eng_ratio10_2gram = np.load('./path/eng_ratio10_2gram_embedding.npy', allow_pickle=True)
eng_ratio10_3gram = np.load('./path/eng_ratio10_3gram_embedding.npy', allow_pickle=True)
eng_ratio10_4gram = np.load('./path/eng_ratio10_4gram_embedding.npy', allow_pickle=True)

# %%
# eng_ratio5_2gram
eng_r5_2g = total_model(eng_ratio5_2gram)
score_result = result_append(score_result, eng_r5_2g)
# Out:
# 304 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9230769230769231
#  f1-score  :  0.9239230064161321
#  recall    :  0.9218106995884774
#  precision :  0.9260450160771704
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7511584800741428
#  f1-score  :  0.7468175388967467
#  recall    :  0.7242798353909465
#  precision :  0.7708029197080292
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8635310472659871
#  f1-score  :  0.8658008658008658
#  recall    :  0.8687700045724737
#  precision :  0.8628519527702089
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9219184430027804
#  f1-score  :  0.9225821272685505
#  recall    :  0.9177330895795247
#  precision :  0.9274826789838337
#  ========= 2 =========
#  accuracy  :  0.9230769230769231
#  f1-score  :  0.9246139872842869
#  recall    :  0.9275626423690205
#  precision :  0.9216840199185151
#  ========= 3 =========
#  accuracy  :  0.9168211306765524
#  f1-score  :  0.919162350821887
#  recall    :  0.9197836863452006
#  precision :  0.9185418541854186
#  ========= 4 =========
#  accuracy  :  0.9309545875810936
#  f1-score  :  0.9312096029547552
#  recall    :  0.929921622867681
#  precision :  0.9325011558021267
#  ========= 5 =========
#  accuracy  :  0.919601482854495
#  f1-score  :  0.9201380897583429
#  recall    :  0.9241793804900601
#  precision :  0.9161319890009166
#  ======== 최종 ========
#  평균검증 정확도   :  0.9224745134383688
#  평균검증 f1-score :  0.9235412316175644
#  평균검증 정밀도   :  0.9238360843302974
#  평균검증 재현율   :  0.923268339578162
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7518535681186284
#  f1-score  :  0.7523699421965319
#  recall    :  0.743601462522852
#  precision :  0.7613476836686944
#  ========= 2 =========
#  accuracy  :  0.7657553290083411
#  f1-score  :  0.7641707487753673
#  recall    :  0.7462414578587699
#  precision :  0.7829827915869981
#  ========= 3 =========
#  accuracy  :  0.75
#  f1-score  :  0.7504048114735137
#  recall    :  0.7309598918431726
#  precision :  0.7709125475285171
#  ========= 4 =========
#  accuracy  :  0.7495366079703429
#  f1-score  :  0.7449870252418023
#  recall    :  0.7279852466574458
#  precision :  0.7628019323671498
#  ========= 5 =========
#  accuracy  :  0.7497683039851715
#  f1-score  :  0.7457627118644068
#  recall    :  0.7323162274618585
#  precision :  0.7597122302158273
#  ======== 최종 ========
#  평균검증 정확도   :  0.7533827618164967
#  평균검증 f1-score :  0.7515390479103244
#  평균검증 정밀도   :  0.7362208572688198
#  평균검증 재현율   :  0.7675514370734373
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8649212233549582
#  f1-score  :  0.8673492605233218
#  recall    :  0.8711151736745887
#  precision :  0.8636157680108745
#  ========= 2 =========
#  accuracy  :  0.8730305838739574
#  f1-score  :  0.8755111313039527
#  recall    :  0.8779043280182233
#  precision :  0.87313094698686
#  ========= 3 =========
#  accuracy  :  0.8595922150139017
#  f1-score  :  0.8620218579234974
#  recall    :  0.8530869761153673
#  precision :  0.8711458812701335
#  ========= 4 =========
#  accuracy  :  0.870713623725672
#  f1-score  :  0.8726608854404382
#  recall    :  0.8815122176118027
#  precision :  0.8639855399909625
#  ========= 5 =========
#  accuracy  :  0.8632993512511585
#  f1-score  :  0.8644301470588235
#  recall    :  0.869625520110957
#  precision :  0.8592964824120602
#  ======== 최종 ========
#  평균검증 정확도   :  0.8663113994439297
#  평균검증 f1-score :  0.8683946564500067
#  평균검증 정밀도   :  0.8706488431061878
#  평균검증 재현율   :  0.8662349237341782
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# eng_ratio5_3gram
eng_r5_3g = total_model(eng_ratio5_3gram)
score_result = result_append(score_result, eng_r5_3g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9548128971522711
#  f1-score  :  0.9555966697502313
#  recall    :  0.9564814814814815
#  precision :  0.9547134935304991
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7905389503412568
#  f1-score  :  0.7925407925407926
#  recall    :  0.7870370370370371
#  precision :  0.7981220657276995
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8985643680866087
#  f1-score  :  0.9009878244888583
#  recall    :  0.9078703703703703
#  precision :  0.8942088463292294
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9416333254883502
#  f1-score  :  0.9422180801491147
#  recall    :  0.9461862423958821
#  precision :  0.9382830626450116
#  ========= 2 =========
#  accuracy  :  0.9510473052482937
#  f1-score  :  0.9523809523809523
#  recall    :  0.9523809523809523
#  precision :  0.9523809523809523
#  ========= 3 =========
#  accuracy  :  0.9524482109227872
#  f1-score  :  0.9540700318326512
#  recall    :  0.957553628480146
#  precision :  0.9506116900770276
#  ========= 4 =========
#  accuracy  :  0.9562146892655368
#  f1-score  :  0.9566635601118361
#  recall    :  0.9557728119180633
#  precision :  0.9575559701492538
#  ========= 5 =========
#  accuracy  :  0.9585687382297552
#  f1-score  :  0.9586077140169332
#  recall    :  0.954119850187266
#  precision :  0.9631379962192816
#  ======== 최종 ========
#  평균검증 정확도   :  0.9519824538309447
#  평균검증 f1-score :  0.9527880676982974
#  평균검증 정밀도   :  0.9532026970724619
#  평균검증 재현율   :  0.9523939342943054
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.785831960461285
#  f1-score  :  0.7842579421526791
#  recall    :  0.7739822180627047
#  precision :  0.7948101874098991
#  ========= 2 =========
#  accuracy  :  0.7832431160273006
#  f1-score  :  0.7869535045107564
#  recall    :  0.7788461538461539
#  precision :  0.7952314165497896
#  ========= 3 =========
#  accuracy  :  0.8001412429378532
#  f1-score  :  0.8021440223724073
#  recall    :  0.7854860794157918
#  precision :  0.8195238095238095
#  ========= 4 =========
#  accuracy  :  0.7961393596986818
#  f1-score  :  0.7957547169811321
#  recall    :  0.7853817504655494
#  precision :  0.8064053537284895
#  ========= 5 =========
#  accuracy  :  0.7937853107344632
#  f1-score  :  0.7911301859799714
#  recall    :  0.776685393258427
#  precision :  0.8061224489795918
#  ======== 최종 ========
#  평균검증 정확도   :  0.7918281979719167
#  평균검증 f1-score :  0.7920480743993893
#  평균검증 정밀도   :  0.7800763190097253
#  평균검증 재현율   :  0.8044186432383158
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8893857378206637
#  f1-score  :  0.891052387575336
#  recall    :  0.8993916705662143
#  precision :  0.8828663298116675
#  ========= 2 =========
#  accuracy  :  0.8959755236526241
#  f1-score  :  0.8982035928143712
#  recall    :  0.8928571428571429
#  precision :  0.9036144578313253
#  ========= 3 =========
#  accuracy  :  0.8975988700564972
#  f1-score  :  0.9013381719210706
#  recall    :  0.9068918302145139
#  precision :  0.8958521190261497
#  ========= 4 =========
#  accuracy  :  0.8973634651600754
#  f1-score  :  0.8996316758747699
#  recall    :  0.909683426443203
#  precision :  0.8897996357012751
#  ========= 5 =========
#  accuracy  :  0.8938323917137476
#  f1-score  :  0.8949941792782306
#  recall    :  0.899812734082397
#  precision :  0.890226956924502
#  ======== 최종 ========
#  평균검증 정확도   :  0.8948311976807215
#  평균검증 f1-score :  0.8970440014927556
#  평균검증 정밀도   :  0.9017273608326942
#  평균검증 재현율   :  0.8924718998589839
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# eng_ratio5_4gram
eng_r5_4g = total_model(eng_ratio5_4gram)
score_result = result_append(score_result, eng_r5_4g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 291 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 331 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9720229555236729
#  f1-score  :  0.9726443768996961
#  recall    :  0.9751523675574308
#  precision :  0.9701492537313433
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.8137254901960784
#  f1-score  :  0.814920408648135
#  recall    :  0.804031879981247
#  precision :  0.8261078998073218
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.9167862266857962
#  f1-score  :  0.9194817214252661
#  recall    :  0.9315518049695265
#  precision :  0.9077204202832344
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.966284074605452
#  f1-score  :  0.966579758236549
#  recall    :  0.9672675521821632
#  precision :  0.9658929417337755
#  ========= 2 =========
#  accuracy  :  0.9751315160210425
#  f1-score  :  0.9758588672237698
#  recall    :  0.9781293624941834
#  precision :  0.9735988883742474
#  ========= 3 =========
#  accuracy  :  0.9720162640516623
#  f1-score  :  0.9730228268388287
#  recall    :  0.9723502304147466
#  precision :  0.9736963544070143
#  ========= 4 =========
#  accuracy  :  0.9739296818942836
#  f1-score  :  0.9745267585884552
#  recall    :  0.9774964838255977
#  precision :  0.9715750232991612
#  ========= 5 =========
#  accuracy  :  0.9674718966754365
#  f1-score  :  0.9676036207717961
#  recall    :  0.9666825321275583
#  precision :  0.9685264663805436
#  ======== 최종 ========
#  평균검증 정확도   :  0.9709666866495754
#  평균검증 f1-score :  0.9715183663318797
#  평균검증 정밀도   :  0.9723852322088499
#  평균검증 재현율   :  0.9706579348389484
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.8118125298900047
#  f1-score  :  0.8118575185273726
#  recall    :  0.8055028462998103
#  precision :  0.8183132530120482
#  ========= 2 =========
#  accuracy  :  0.8134863701578192
#  f1-score  :  0.8159509202453987
#  recall    :  0.8045602605863192
#  precision :  0.8276687410244136
#  ========= 3 =========
#  accuracy  :  0.8043530255919636
#  f1-score  :  0.8066193853427897
#  recall    :  0.7861751152073733
#  precision :  0.8281553398058252
#  ========= 4 =========
#  accuracy  :  0.8100932791198278
#  f1-score  :  0.8137024870952605
#  recall    :  0.8129395218002813
#  precision :  0.814466885861907
#  ========= 5 =========
#  accuracy  :  0.8177469504903133
#  f1-score  :  0.8168269230769231
#  recall    :  0.8086625416468348
#  precision :  0.8251578436134046
#  ======== 최종 ========
#  평균검증 정확도   :  0.8114984310499859
#  평균검증 f1-score :  0.8129914468575489
#  평균검증 정밀도   :  0.8035680571081238
#  평균검증 재현율   :  0.8227524126635197
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.9170253467240554
#  f1-score  :  0.9178309258820744
#  recall    :  0.9193548387096774
#  precision :  0.9163120567375886
#  ========= 2 =========
#  accuracy  :  0.9191774270683883
#  f1-score  :  0.9217954650624711
#  recall    :  0.9269427640763146
#  precision :  0.9167050161067648
#  ========= 3 =========
#  accuracy  :  0.9186797416885912
#  f1-score  :  0.9218749999999999
#  recall    :  0.9244239631336405
#  precision :  0.919340054995417
#  ========= 4 =========
#  accuracy  :  0.9174838555369529
#  f1-score  :  0.9203784906531273
#  recall    :  0.9348335677449602
#  precision :  0.9063636363636364
#  ========= 5 =========
#  accuracy  :  0.9160487921549868
#  f1-score  :  0.9169623846699787
#  recall    :  0.9224178962398858
#  precision :  0.9115710253998118
#  ======== 최종 ========
#  평균검증 정확도   :  0.917683032634595
#  평균검증 f1-score :  0.9197684532535304
#  평균검증 정밀도   :  0.9255946059808957
#  평균검증 재현율   :  0.9140583579206437
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# eng_ratio10_2gram
eng_r10_2g = total_model(eng_ratio10_2gram)
score_result = result_append(score_result, eng_r10_2g)
# Out:
# 304 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9230769230769231
#  f1-score  :  0.9238532110091744
#  recall    :  0.9208962048468221
#  precision :  0.926829268292683
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7493049119555144
#  f1-score  :  0.7466042154566745
#  recall    :  0.7288523090992227
#  precision :  0.7652424387902065
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8591288229842446
#  f1-score  :  0.8615034168564921
#  recall    :  0.8646547782350251
#  precision :  0.8583749432591921
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9212233549582948
#  f1-score  :  0.9219108865411115
#  recall    :  0.9172760511882998
#  precision :  0.9265927977839336
#  ========= 2 =========
#  accuracy  :  0.9198331788693235
#  f1-score  :  0.9213636363636364
#  recall    :  0.9234624145785877
#  precision :  0.9192743764172335
#  ========= 3 =========
#  accuracy  :  0.9142724745134384
#  f1-score  :  0.9167791273054431
#  recall    :  0.918431726002704
#  precision :  0.9151324651998204
#  ========= 4 =========
#  accuracy  :  0.9291010194624653
#  f1-score  :  0.9294605809128631
#  recall    :  0.9294605809128631
#  precision :  0.9294605809128631
#  ========= 5 =========
#  accuracy  :  0.9186746987951807
#  f1-score  :  0.9194029850746269
#  recall    :  0.9255663430420712
#  precision :  0.9133211678832117
#  ======== 최종 ========
#  평균검증 정확도   :  0.9206209453197405
#  평균검증 f1-score :  0.9217834432395362
#  평균검증 정밀도   :  0.9228394231449052
#  평균검증 재현율   :  0.9207562776394125
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7511584800741428
#  f1-score  :  0.753216911764706
#  recall    :  0.7490859232175503
#  precision :  0.7573937153419593
#  ========= 2 =========
#  accuracy  :  0.7574142724745134
#  f1-score  :  0.7581427581427582
#  recall    :  0.7476082004555809
#  precision :  0.7689784442361762
#  ========= 3 =========
#  accuracy  :  0.747451343836886
#  f1-score  :  0.7498852684717761
#  recall    :  0.7363677332131591
#  precision :  0.7639083683964469
#  ========= 4 =========
#  accuracy  :  0.7446709916589435
#  f1-score  :  0.7414359455654622
#  recall    :  0.7284462886122637
#  precision :  0.754897276636407
#  ========= 5 =========
#  accuracy  :  0.7506950880444856
#  f1-score  :  0.749534450651769
#  recall    :  0.7443365695792881
#  precision :  0.7548054383497421
#  ======== 최종 ========
#  평균검증 정확도   :  0.7502780352177943
#  평균검증 f1-score :  0.7504430669192944
#  평균검증 정밀도   :  0.7411689430155685
#  평균검증 재현율   :  0.7599966485921462
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8639944392956441
#  f1-score  :  0.8671043694815486
#  recall    :  0.8752285191956124
#  precision :  0.8591296545536115
#  ========= 2 =========
#  accuracy  :  0.8716404077849861
#  f1-score  :  0.8747173224785165
#  recall    :  0.8810933940774488
#  precision :  0.8684328693309384
#  ========= 3 =========
#  accuracy  :  0.8561167747914736
#  f1-score  :  0.8595340420719294
#  recall    :  0.8562415502478594
#  precision :  0.8628519527702089
#  ========= 4 =========
#  accuracy  :  0.8651529193697869
#  f1-score  :  0.8666972056802564
#  recall    :  0.8722913785154449
#  precision :  0.8611743286299499
#  ========= 5 =========
#  accuracy  :  0.8619091751621872
#  f1-score  :  0.8635531135531135
#  recall    :  0.8719371243643088
#  precision :  0.8553287981859411
#  ======== 최종 ========
#  평균검증 정확도   :  0.8637627432808156
#  평균검증 f1-score :  0.8663212106530729
#  평균검증 정밀도   :  0.8713583932801349
#  평균검증 재현율   :  0.8613835206941299
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# eng_ratio10_3gram
eng_r10_3g = total_model(eng_ratio10_3gram)
score_result = result_append(score_result, eng_r10_3g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.953165450694281
#  f1-score  :  0.9539031735001158
#  recall    :  0.9532407407407407
#  precision :  0.9545665275846082
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7841845140032949
#  f1-score  :  0.7877806063411248
#  recall    :  0.787962962962963
#  precision :  0.7875983341045812
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8938573782066369
#  f1-score  :  0.8966307586523035
#  recall    :  0.9055555555555556
#  precision :  0.887880163413527
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9456342668863262
#  f1-score  :  0.9459901800327332
#  recall    :  0.9466541881141788
#  precision :  0.9453271028037383
#  ========= 2 =========
#  accuracy  :  0.9510473052482937
#  f1-score  :  0.9524680073126143
#  recall    :  0.9542124542124543
#  precision :  0.9507299270072993
#  ========= 3 =========
#  accuracy  :  0.9524482109227872
#  f1-score  :  0.9539023277042448
#  recall    :  0.9539023277042447
#  precision :  0.9539023277042447
#  ========= 4 =========
#  accuracy  :  0.9559792843691148
#  f1-score  :  0.9563593932322054
#  recall    :  0.9539106145251397
#  precision :  0.9588207767898924
#  ========= 5 =========
#  accuracy  :  0.9583333333333334
#  f1-score  :  0.9584994138335287
#  recall    :  0.9569288389513109
#  precision :  0.960075152653828
#  ======== 최종 ========
#  평균검증 정확도   :  0.952688480151971
#  평균검증 f1-score :  0.9534438644230653
#  평균검증 정밀도   :  0.9531216847014656
#  평균검증 재현율   :  0.9537710573918006
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7832431160273006
#  f1-score  :  0.7836504580690627
#  recall    :  0.7805334581188582
#  precision :  0.7867924528301887
#  ========= 2 =========
#  accuracy  :  0.7766533301953401
#  f1-score  :  0.7809831525501962
#  recall    :  0.7747252747252747
#  precision :  0.7873429502093997
#  ========= 3 =========
#  accuracy  :  0.7996704331450094
#  f1-score  :  0.8030548484147189
#  recall    :  0.7918758557736193
#  precision :  0.8145539906103286
#  ========= 4 =========
#  accuracy  :  0.7930790960451978
#  f1-score  :  0.7933223606865741
#  recall    :  0.7853817504655494
#  precision :  0.8014251781472684
#  ========= 5 =========
#  accuracy  :  0.7848399246704332
#  f1-score  :  0.7850423330197555
#  recall    :  0.7813670411985019
#  precision :  0.7887523629489603
#  ======== 최종 ========
#  평균검증 정확도   :  0.7874971800166563
#  평균검증 f1-score :  0.7892106305480615
#  평균검증 정밀도   :  0.7827766760563607
#  평균검증 재현율   :  0.7957733869492292
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8832666509767004
#  f1-score  :  0.8849721706864563
#  recall    :  0.8928404305100608
#  precision :  0.8772413793103448
#  ========= 2 =========
#  accuracy  :  0.8898564368086609
#  f1-score  :  0.8928080622995878
#  recall    :  0.8923992673992674
#  precision :  0.8932172318973419
#  ========= 3 =========
#  accuracy  :  0.8990112994350282
#  f1-score  :  0.9026990247221591
#  recall    :  0.9082610680054769
#  precision :  0.8972046889089269
#  ========= 4 =========
#  accuracy  :  0.8987758945386064
#  f1-score  :  0.900555041628122
#  recall    :  0.9064245810055865
#  precision :  0.8947610294117647
#  ========= 5 =========
#  accuracy  :  0.8907721280602636
#  f1-score  :  0.8921933085501859
#  recall    :  0.898876404494382
#  precision :  0.8856088560885609
#  ======== 최종 ========
#  평균검증 정확도   :  0.8923364819638518
#  평균검증 f1-score :  0.8946455215773023
#  평균검증 정밀도   :  0.8997603502829549
#  평균검증 재현율   :  0.8896066371233878
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# eng_ratio10_4gram
eng_r10_4g = total_model(eng_ratio10_4gram)
score_result = result_append(score_result, eng_r10_4g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 291 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 331 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9681970349115255
#  f1-score  :  0.9689034369885433
#  recall    :  0.9714017815283638
#  precision :  0.9664179104477612
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.810856049736968
#  f1-score  :  0.8137508829762186
#  recall    :  0.810126582278481
#  precision :  0.8174077578051088
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.912960306073649
#  f1-score  :  0.9156626506024096
#  recall    :  0.9263947491795593
#  precision :  0.9051763628034815
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9672405547584888
#  f1-score  :  0.9675124496087266
#  recall    :  0.967741935483871
#  precision :  0.9672830725462305
#  ========= 2 =========
#  accuracy  :  0.9734576757532282
#  f1-score  :  0.9742040436904486
#  recall    :  0.9753373662168451
#  precision :  0.9730733519034355
#  ========= 3 =========
#  accuracy  :  0.9701028462090409
#  f1-score  :  0.9710312862108923
#  recall    :  0.9654377880184332
#  precision :  0.9766899766899767
#  ========= 4 =========
#  accuracy  :  0.9705812006696962
#  f1-score  :  0.971201123858581
#  recall    :  0.9723394280356306
#  precision :  0.9700654817586529
#  ========= 5 =========
#  accuracy  :  0.9660368332934705
#  f1-score  :  0.9661582459485223
#  recall    :  0.9647786768205616
#  precision :  0.9675417661097852
#  ======== 최종 ========
#  평균검증 정확도   :  0.969483822136785
#  평균검증 f1-score :  0.9700214298634341
#  평균검증 정밀도   :  0.9691270389150682
#  평균검증 재현율   :  0.9709307298016162
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.8091822094691535
#  f1-score  :  0.8096374045801527
#  recall    :  0.8050284629981025
#  precision :  0.814299424184261
#  ========= 2 =========
#  accuracy  :  0.8113342898134863
#  f1-score  :  0.8149190710767066
#  recall    :  0.808282922289437
#  precision :  0.8216650898770104
#  ========= 3 =========
#  accuracy  :  0.8079406840468787
#  f1-score  :  0.8121637426900585
#  recall    :  0.8
#  precision :  0.8247030878859858
#  ========= 4 =========
#  accuracy  :  0.801961253288687
#  f1-score  :  0.8066324147594582
#  recall    :  0.8096577590248476
#  precision :  0.8036295951605398
#  ========= 5 =========
#  accuracy  :  0.8072231523558957
#  f1-score  :  0.80726924916308
#  recall    :  0.803426939552594
#  precision :  0.8111484863046612
#  ======== 최종 ========
#  평균검증 정확도   :  0.8075283177948203
#  평균검증 f1-score :  0.8101243764538912
#  평균검증 정밀도   :  0.8052792167729963
#  평균검증 재현율   :  0.8150891366824917
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.9184600669536107
#  f1-score  :  0.9194805194805195
#  recall    :  0.9236242884250474
#  precision :  0.9153737658674189
#  ========= 2 =========
#  accuracy  :  0.9184600669536107
#  f1-score  :  0.921265296698222
#  recall    :  0.9283387622149837
#  precision :  0.9142988084326306
#  ========= 3 =========
#  accuracy  :  0.9177230327672805
#  f1-score  :  0.9212093449381585
#  recall    :  0.9267281105990783
#  precision :  0.9157559198542805
#  ========= 4 =========
#  accuracy  :  0.9117436020090888
#  f1-score  :  0.9147215160619367
#  recall    :  0.9278012189404594
#  precision :  0.9020054694621695
#  ========= 5 =========
#  accuracy  :  0.9129394881607271
#  f1-score  :  0.9139072847682119
#  recall    :  0.9195621132793907
#  precision :  0.9083215796897038
#  ======== 최종 ========
#  평균검증 정확도   :  0.9158652513688637
#  평균검증 f1-score :  0.9181167923894098
#  평균검증 정밀도   :  0.9252108986917917
#  평균검증 재현율   :  0.9111511086612406
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# 나온 결과 확인
score_result
# Out:
#    logistic_Acc  logistic_F1  logistic_Rec  logistic_Pre  naivebayes_Acc  \
# 0      0.802690     0.718678      0.716074      0.721301        0.676096
# 1      0.838436     0.779279      0.812752      0.748455        0.710551
# 2      0.845418     0.782784      0.796715      0.769332        0.720268
# 3      0.923077     0.923923      0.921811      0.926045        0.751158
# 4      0.954813     0.955597      0.956481      0.954713        0.790539
# 5      0.972023     0.972644      0.975152      0.970149        0.813725
# 6      0.923077     0.923853      0.920896      0.926829        0.749305
# 7      0.953165     0.953903      0.953241      0.954567        0.784185
# 8      0.968197     0.968903      0.971402      0.966418        0.810856
#
#    naivebayes_F1  naivebayes_Rec  naivebayes_Pre  randomforest_Acc  \
# 0       0.619035        0.747694        0.528153          0.765129
# 1       0.652530        0.774497        0.563752          0.796514
# 2       0.659680        0.775496        0.573961          0.822446
# 3       0.746818        0.724280        0.770803          0.863531
# 4       0.792541        0.787037        0.798122          0.898564
# 5       0.814920        0.804032        0.826108          0.916786
# 6       0.746604        0.728852        0.765242          0.859129
# 7       0.787781        0.787963        0.787598          0.893857
# 8       0.813751        0.810127        0.817408          0.912960
#
#    logistic_F1  ...  logistic_5fold_Rec  logistic_5fold_Pre  \
# 0     0.624397  ...            0.732543            0.714478
# 1     0.691429  ...            0.781084            0.746030
# 2     0.730964  ...            0.808992            0.768530
# 3     0.865801  ...            0.923836            0.923268
# 4     0.900988  ...            0.953203            0.952394
# 5     0.919482  ...            0.972385            0.970658
# 6     0.861503  ...            0.922839            0.920756
# 7     0.896631  ...            0.953122            0.953771
# 8     0.915663  ...            0.969127            0.970931
#
#    naivebayes_5Fold_Acc  naivebayes_5Fold_F1  naivebayes_5Fold_Rec  \
# 0              0.677116             0.618273              0.743248
# 1              0.707684             0.648572              0.769117
# 2              0.731237             0.672366              0.788459
# 3              0.753383             0.751539              0.736221
# 4              0.791828             0.792048              0.780076
# 5              0.811498             0.812991              0.803568
# 6              0.750278             0.750443              0.741169
# 7              0.787497             0.789211              0.782777
# 8              0.807528             0.810124              0.805279
#
#    naivebayes_5Fold_Pre  randomforest_5Fold_Acc  randomforest_5Fold_F1  \
# 0              0.529307                0.770971               0.637507
# 1              0.560772                0.796957               0.689493
# 2              0.586130                0.825244               0.738567
# 3              0.767551                0.866311               0.868395
# 4              0.804419                0.894831               0.897044
# 5              0.822752                0.917683               0.919768
# 6              0.759997                0.863763               0.866321
# 7              0.795773                0.892336               0.894646
# 8              0.815089                0.915865               0.918117
#
#    randomforest_5Fold_Rec  randomforest_5Fold_Pre
# 0                0.572475                0.719289
# 1                0.642843                0.743520
# 2                0.705796                0.774678
# 3                0.870649                0.866235
# 4                0.901727                0.892472
# 5                0.925595                0.914058
# 6                0.871358                0.861384
# 7                0.899760                0.889607
# 8                0.925211                0.911151
#
# [9 rows x 24 columns]

# %% [markdown]
# ### 모델 이용 데이터셋 분류: kor

# %%
# 데이터 로드
kor_ratio5_2gram = np.load('./path/kor_ratio5_2gram_embedding.npy', allow_pickle=True)
kor_ratio5_3gram = np.load('./path/kor_ratio5_3gram_embedding.npy', allow_pickle=True)
kor_ratio5_4gram = np.load('./path/kor_ratio5_4gram_embedding.npy', allow_pickle=True)

kor_ratio10_2gram = np.load('./path/kor_ratio10_2gram_embedding.npy', allow_pickle=True)
kor_ratio10_3gram = np.load('./path/kor_ratio10_3gram_embedding.npy', allow_pickle=True)
kor_ratio10_4gram = np.load('./path/kor_ratio10_4gram_embedding.npy', allow_pickle=True)

# %%
# kor_ratio5_2gram
kor_r5_2g = total_model(kor_ratio5_2gram)
score_result = result_append(score_result, kor_r5_2g)
# Out:
# 104 번 인덱스 오류 처리 완료
# 130 번 인덱스 오류 처리 완료
# 132 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.7992116856016693
#  f1-score  :  0.7143799472295513
#  recall    :  0.7134387351778656
#  precision :  0.7153236459709379
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.6886158126594019
#  f1-score  :  0.6317521250342748
#  recall    :  0.758893280632411
#  precision :  0.5410991075622358
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.7667516809645258
#  f1-score  :  0.6333819241982508
#  recall    :  0.572463768115942
#  precision :  0.7088091353996737
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.7941108277301182
#  f1-score  :  0.7111255692908264
#  recall    :  0.7148463047743623
#  precision :  0.7074433656957929
#  ========= 2 =========
#  accuracy  :  0.8003709714815673
#  f1-score  :  0.7179823124795283
#  recall    :  0.7282392026578073
#  precision :  0.7080103359173127
#  ========= 3 =========
#  accuracy  :  0.8038488291212613
#  f1-score  :  0.7270967741935485
#  recall    :  0.7434036939313984
#  precision :  0.711489898989899
#  ========= 4 =========
#  accuracy  :  0.8108045444006492
#  f1-score  :  0.7364341085271316
#  recall    :  0.7534699272967614
#  precision :  0.7201516108654453
#  ========= 5 =========
#  accuracy  :  0.8040806862972409
#  f1-score  :  0.7239464227376673
#  recall    :  0.7265573770491803
#  precision :  0.7213541666666666
#  ======== 최종 ========
#  평균검증 정확도   :  0.8026431718061675
#  평균검증 f1-score :  0.7233170374457404
#  평균검증 정밀도   :  0.733303301141902
#  평균검증 재현율   :  0.7136898756270232
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.6753999536285648
#  f1-score  :  0.6176952484980884
#  recall    :  0.7396991497710922
#  precision :  0.530239099859353
#  ========= 2 =========
#  accuracy  :  0.6876883839554834
#  f1-score  :  0.6200282087447109
#  recall    :  0.7302325581395349
#  precision :  0.5387254901960784
#  ========= 3 =========
#  accuracy  :  0.6944122420588917
#  f1-score  :  0.6342952275249722
#  recall    :  0.753957783641161
#  precision :  0.5474137931034483
#  ========= 4 =========
#  accuracy  :  0.686760955251565
#  f1-score  :  0.6309751434034416
#  recall    :  0.7633840052875083
#  precision :  0.5377094972067039
#  ========= 5 =========
#  accuracy  :  0.6888476698353814
#  f1-score  :  0.6323287671232877
#  recall    :  0.7567213114754099
#  precision :  0.5430588235294118
#  ======== 최종 ========
#  평균검증 정확도   :  0.6866218409459772
#  평균검증 f1-score :  0.6270645190589003
#  평균검증 정밀도   :  0.7487989616629411
#  평균검증 재현율   :  0.5394293407789992
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.7616508230929747
#  f1-score  :  0.6296829971181556
#  recall    :  0.5716154349247874
#  precision :  0.7008821170809943
#  ========= 2 =========
#  accuracy  :  0.763273823324832
#  f1-score  :  0.6277798031352533
#  recall    :  0.5720930232558139
#  precision :  0.6954765751211631
#  ========= 3 =========
#  accuracy  :  0.7746348249478321
#  f1-score  :  0.6508620689655173
#  recall    :  0.5976253298153035
#  precision :  0.7145110410094637
#  ========= 4 =========
#  accuracy  :  0.7820542545791792
#  f1-score  :  0.6657183499288762
#  recall    :  0.6186384666226041
#  precision :  0.7205542725173211
#  ========= 5 =========
#  accuracy  :  0.7690702527243218
#  f1-score  :  0.6412103746397695
#  recall    :  0.5836065573770491
#  precision :  0.7114308553157475
#  ======== 최종 ========
#  평균검증 정확도   :  0.7701367957338279
#  평균검증 f1-score :  0.6430507187575143
#  평균검증 정밀도   :  0.5887157623991115
#  평균검증 재현율   :  0.7085709722089379
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# kor_ratio5_3gram
kor_r5_3g = total_model(kor_ratio5_3gram)
score_result = result_append(score_result, kor_r5_3g)
# Out:
# 64 번 인덱스 오류 처리 완료
# 104 번 인덱스 오류 처리 완료
# 116 번 인덱스 오류 처리 완료
# 130 번 인덱스 오류 처리 완료
# 132 번 인덱스 오류 처리 완료
# 134 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.833254828073481
#  f1-score  :  0.7717601547388782
#  recall    :  0.8033557046979866
#  precision :  0.7425558312655087
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7183231276495525
#  f1-score  :  0.6625282167042889
#  recall    :  0.7879194630872484
#  precision :  0.5715676728334956
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.796514366462553
#  f1-score  :  0.700831024930748
#  recall    :  0.6791946308724832
#  precision :  0.7238912732474965
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.826189354686764
#  f1-score  :  0.7501692620176031
#  recall    :  0.7604667124227865
#  precision :  0.7401469605878424
#  ========= 2 =========
#  accuracy  :  0.8257183231276496
#  f1-score  :  0.7637292464878672
#  recall    :  0.78580814717477
#  precision :  0.7428571428571429
#  ========= 3 =========
#  accuracy  :  0.8275618374558303
#  f1-score  :  0.7655349135169763
#  recall    :  0.7924403183023873
#  precision :  0.7403965303593556
#  ========= 4 =========
#  accuracy  :  0.8256772673733804
#  f1-score  :  0.7570584372948129
#  recall    :  0.7843537414965986
#  precision :  0.7315989847715736
#  ========= 5 =========
#  accuracy  :  0.8299175500588928
#  f1-score  :  0.7601328903654485
#  recall    :  0.7677852348993288
#  precision :  0.7526315789473684
#  ======== 최종 ========
#  평균검증 정확도   :  0.8270128665405034
#  평균검증 f1-score :  0.7593249499365416
#  평균검증 정밀도   :  0.7781708308591743
#  평균검증 재현율   :  0.7415262395046566
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7162034856335374
#  f1-score  :  0.6473514779045948
#  recall    :  0.7590940288263556
#  precision :  0.5642857142857143
#  ========= 2 =========
#  accuracy  :  0.7079604333490344
#  f1-score  :  0.6568898727172109
#  recall    :  0.7798948751642576
#  precision :  0.5673996175908221
#  ========= 3 =========
#  accuracy  :  0.71849234393404
#  f1-score  :  0.6686997504851677
#  recall    :  0.7997347480106101
#  precision :  0.5745593139590282
#  ========= 4 =========
#  accuracy  :  0.7250883392226148
#  f1-score  :  0.6618371486525646
#  recall    :  0.7768707482993197
#  precision :  0.5764765270065624
#  ========= 5 =========
#  accuracy  :  0.713545347467609
#  f1-score  :  0.6535612535612535
#  recall    :  0.7697986577181208
#  precision :  0.5678217821782178
#  ======== 최종 ========
#  평균검증 정확도   :  0.7162579899213671
#  평균검증 f1-score :  0.6576679006641583
#  평균검증 정밀도   :  0.7770786116037328
#  평균검증 재현율   :  0.5701085910040689
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.796514366462553
#  f1-score  :  0.6862745098039216
#  recall    :  0.6485929993136582
#  precision :  0.7286044718581342
#  ========= 2 =========
#  accuracy  :  0.7920395666509656
#  f1-score  :  0.6917975567190227
#  recall    :  0.6511169513797634
#  precision :  0.7379002233804914
#  ========= 3 =========
#  accuracy  :  0.8023557126030624
#  f1-score  :  0.7093869068236923
#  recall    :  0.6790450928381963
#  precision :  0.7425670775924583
#  ========= 4 =========
#  accuracy  :  0.8044758539458187
#  f1-score  :  0.7058823529411764
#  recall    :  0.6775510204081633
#  precision :  0.7366863905325444
#  ========= 5 =========
#  accuracy  :  0.7962308598351001
#  f1-score  :  0.6891843334531081
#  recall    :  0.6436241610738255
#  precision :  0.7416860015467904
#  ======== 최종 ========
#  평균검증 정확도   :  0.7983232718994999
#  평균검증 f1-score :  0.6965051319481842
#  평균검증 정밀도   :  0.6599860450027213
#  평균검증 재현율   :  0.7374888329820837
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# kor_ratio5_4gram
kor_r5_4g = total_model(kor_ratio5_4gram)
score_result = result_append(score_result, kor_r5_4g)
# Out:
# 64 번 인덱스 오류 처리 완료
# 91 번 인덱스 오류 처리 완료
# 104 번 인덱스 오류 처리 완료
# 116 번 인덱스 오류 처리 완료
# 130 번 인덱스 오류 처리 완료
# 131 번 인덱스 오류 처리 완료
# 132 번 인덱스 오류 처리 완료
# 134 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.8396745632926538
#  f1-score  :  0.7733423545331529
#  recall    :  0.7823408624229979
#  precision :  0.7645484949832776
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7284039243838238
#  f1-score  :  0.6686131386861314
#  recall    :  0.783709787816564
#  precision :  0.5829938900203666
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8332136874850443
#  f1-score  :  0.7534488857446056
#  recall    :  0.728952772073922
#  precision :  0.7796486090775988
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.8499641062455133
#  f1-score  :  0.7841652323580035
#  recall    :  0.8021126760563381
#  precision :  0.767003367003367
#  ========= 2 =========
#  accuracy  :  0.8406317300789663
#  f1-score  :  0.783203125
#  recall    :  0.8079247817327065
#  precision :  0.7599494630448516
#  ========= 3 =========
#  accuracy  :  0.8410722833891814
#  f1-score  :  0.781435154707044
#  recall    :  0.80858310626703
#  precision :  0.7560509554140128
#  ========= 4 =========
#  accuracy  :  0.8499281953087602
#  f1-score  :  0.7920398009950249
#  recall    :  0.8133514986376021
#  precision :  0.7718164188752424
#  ========= 5 =========
#  accuracy  :  0.8465773097175682
#  f1-score  :  0.7851156553804893
#  recall    :  0.8015058179329226
#  precision :  0.7693823915900131
#  ======== 최종 ========
#  평균검증 정확도   :  0.8456347249479979
#  평균검증 f1-score :  0.7851917936881123
#  평균검증 정밀도   :  0.80669557612532
#  평균검증 재현율   :  0.7648405191854974
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.747307968413496
#  f1-score  :  0.6838323353293414
#  recall    :  0.8042253521126761
#  precision :  0.5947916666666667
#  ========= 2 =========
#  accuracy  :  0.7339076334051209
#  f1-score  :  0.6819221967963387
#  recall    :  0.8005372733378107
#  precision :  0.5939212755356253
#  ========= 3 =========
#  accuracy  :  0.7211584490186692
#  f1-score  :  0.6664758087603779
#  recall    :  0.7929155313351499
#  precision :  0.5748148148148148
#  ========= 4 =========
#  accuracy  :  0.7515557683101962
#  f1-score  :  0.6928994082840237
#  recall    :  0.797683923705722
#  precision :  0.6124476987447699
#  ========= 5 =========
#  accuracy  :  0.7288176160842509
#  f1-score  :  0.6682284040995607
#  recall    :  0.7809719370294319
#  precision :  0.5839303991811668
#  ======== 최종 ========
#  평균검증 정확도   :  0.7365494870463467
#  평균검증 f1-score :  0.6786716306539284
#  평균검증 정밀도   :  0.7952668035041581
#  평균검증 재현율   :  0.5919811709886087
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8293850203397942
#  f1-score  :  0.744901610017889
#  recall    :  0.7330985915492958
#  precision :  0.757090909090909
#  ========= 2 =========
#  accuracy  :  0.8162239770279971
#  f1-score  :  0.7338877338877339
#  recall    :  0.7112155809267965
#  precision :  0.7580529706513959
#  ========= 3 =========
#  accuracy  :  0.8204882719004308
#  f1-score  :  0.7394023627519111
#  recall    :  0.7247956403269755
#  precision :  0.7546099290780142
#  ========= 4 =========
#  accuracy  :  0.8336524652943992
#  f1-score  :  0.7553678282294967
#  recall    :  0.7309264305177112
#  precision :  0.7815003641660597
#  ========= 5 =========
#  accuracy  :  0.8207276208712303
#  f1-score  :  0.732595501606569
#  recall    :  0.702258726899384
#  precision :  0.7656716417910447
#  ======== 최종 ========
#  평균검증 정확도   :  0.8240954710867703
#  평균검증 f1-score :  0.74123100729872
#  평균검증 정밀도   :  0.7204589940440327
#  평균검증 재현율   :  0.7633851629554848
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# kor_ratio10_2gram
kor_r10_2g = total_model(kor_ratio10_2gram)
score_result = result_append(score_result, kor_r10_2g)
# Out:
# 104 번 인덱스 오류 처리 완료
# 130 번 인덱스 오류 처리 완료
# 132 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.7978205425457918
#  f1-score  :  0.7140983606557377
#  recall    :  0.717391304347826
#  precision :  0.7108355091383812
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.6862972408996059
#  f1-score  :  0.6296194908294553
#  recall    :  0.7575757575757576
#  precision :  0.5386416861826698
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.7723162531880362
#  f1-score  :  0.6444605358435916
#  recall    :  0.5862977602108037
#  precision :  0.7154340836012861
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.7894736842105263
#  f1-score  :  0.7057679844458847
#  recall    :  0.7122302158273381
#  precision :  0.6994219653179191
#  ========= 2 =========
#  accuracy  :  0.7992116856016693
#  f1-score  :  0.7143799472295514
#  recall    :  0.7196013289036545
#  precision :  0.7092337917485265
#  ========= 3 =========
#  accuracy  :  0.8022258288894041
#  f1-score  :  0.7252818035426731
#  recall    :  0.7427440633245382
#  precision :  0.7086217747010699
#  ========= 4 =========
#  accuracy  :  0.8068629724089961
#  f1-score  :  0.7294576161091263
#  recall    :  0.7422339722405816
#  precision :  0.7171136653895275
#  ========= 5 =========
#  accuracy  :  0.7985161140737306
#  f1-score  :  0.7157343801112201
#  recall    :  0.7173770491803279
#  precision :  0.7140992167101827
#  ======== 최종 ========
#  평균검증 정확도   :  0.7992580570368653
#  평균검증 f1-score :  0.7181243462876912
#  평균검증 정밀도   :  0.726837325895288
#  평균검증 재현율   :  0.7096980827734451
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.6740088105726872
#  f1-score  :  0.6164757228587016
#  recall    :  0.7390451275343362
#  precision :  0.5287786616752457
#  ========= 2 =========
#  accuracy  :  0.6844423834917691
#  f1-score  :  0.6160789844851905
#  recall    :  0.7255813953488373
#  precision :  0.5352941176470588
#  ========= 3 =========
#  accuracy  :  0.6923255274750754
#  f1-score  :  0.6333241226858247
#  recall    :  0.7559366754617414
#  precision :  0.5449358059914408
#  ========= 4 =========
#  accuracy  :  0.6893113841873406
#  f1-score  :  0.633879781420765
#  recall    :  0.7666886979510905
#  precision :  0.5402887750349324
#  ========= 5 =========
#  accuracy  :  0.6888476698353814
#  f1-score  :  0.6313186813186814
#  recall    :  0.7534426229508197
#  precision :  0.5432624113475177
#  ======== 최종 ========
#  평균검증 정확도   :  0.6857871551124507
#  평균검증 f1-score :  0.6262154585538326
#  평균검증 정밀도   :  0.748138903849365
#  평균검증 재현율   :  0.5385119543392392
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.7635056805008115
#  f1-score  :  0.6309696092619392
#  recall    :  0.5703073904512753
#  precision :  0.7060728744939271
#  ========= 2 =========
#  accuracy  :  0.7623463946209135
#  f1-score  :  0.6271371407784649
#  recall    :  0.5727574750830565
#  precision :  0.6929260450160771
#  ========= 3 =========
#  accuracy  :  0.7748666821238117
#  f1-score  :  0.6478055857816467
#  recall    :  0.5890501319261213
#  precision :  0.7195809830781628
#  ========= 4 =========
#  accuracy  :  0.7757941108277301
#  f1-score  :  0.6527827648114901
#  recall    :  0.6007931262392597
#  precision :  0.714622641509434
#  ========= 5 =========
#  accuracy  :  0.7630419661488523
#  f1-score  :  0.6326383896477354
#  recall    :  0.5770491803278689
#  precision :  0.700079554494829
#  ======== 최종 ========
#  평균검증 정확도   :  0.7679109668444237
#  평균검증 f1-score :  0.6382666980562552
#  평균검증 정밀도   :  0.5819914608055163
#  평균검증 재현율   :  0.706656419718486
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# kor_ratio10_3gram
kor_r10_3g = total_model(kor_ratio10_3gram)
score_result = result_append(score_result, kor_r10_3g)
# Out:
# 64 번 인덱스 오류 처리 완료
# 104 번 인덱스 오류 처리 완료
# 116 번 인덱스 오류 처리 완료
# 130 번 인덱스 오류 처리 완료
# 132 번 인덱스 오류 처리 완료
# 134 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.833254828073481
#  f1-score  :  0.7714654615881213
#  recall    :  0.802013422818792
#  precision :  0.7431592039800995
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7164390014130947
#  f1-score  :  0.6598870056497175
#  recall    :  0.7838926174496644
#  precision :  0.5697560975609756
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8052284503061705
#  f1-score  :  0.7129468934397779
#  recall    :  0.689261744966443
#  precision :  0.7383177570093458
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.8219500706547339
#  f1-score  :  0.7437288135593221
#  recall    :  0.7529169526424159
#  precision :  0.7347622237106497
#  ========= 2 =========
#  accuracy  :  0.82312764955252
#  f1-score  :  0.75968
#  recall    :  0.7798948751642576
#  precision :  0.7404865876481597
#  ========= 3 =========
#  accuracy  :  0.8254416961130742
#  f1-score  :  0.7627281460134487
#  recall    :  0.7897877984084881
#  precision :  0.7374613003095976
#  ========= 4 =========
#  accuracy  :  0.8266195524146054
#  f1-score  :  0.7559681697612732
#  recall    :  0.7755102040816326
#  precision :  0.7373868046571799
#  ========= 5 =========
#  accuracy  :  0.8280329799764429
#  f1-score  :  0.7585978835978836
#  recall    :  0.7697986577181208
#  precision :  0.7477183833116037
#  ======== 최종 ========
#  평균검증 정확도   :  0.8250343897422752
#  평균검증 f1-score :  0.7561406025863856
#  평균검증 정밀도   :  0.7735816976029831
#  평균검증 재현율   :  0.7395630599274381
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7114931700423929
#  f1-score  :  0.6410782302959274
#  recall    :  0.7508579272477693
#  precision :  0.5593047034764826
#  ========= 2 =========
#  accuracy  :  0.7072538860103627
#  f1-score  :  0.6565349544072948
#  recall    :  0.7805519053876478
#  precision :  0.5665236051502146
#  ========= 3 =========
#  accuracy  :  0.7166077738515901
#  f1-score  :  0.6662968099861304
#  recall    :  0.7964190981432361
#  precision :  0.5727229375298045
#  ========= 4 =========
#  accuracy  :  0.72226148409894
#  f1-score  :  0.6581617860249348
#  recall    :  0.7721088435374149
#  precision :  0.573521980798383
#  ========= 5 =========
#  accuracy  :  0.7104829210836278
#  f1-score  :  0.6509514342516332
#  recall    :  0.7691275167785235
#  precision :  0.5642540620384048
#  ======== 최종 ========
#  평균검증 정확도   :  0.7136198470173827
#  평균검증 f1-score :  0.6546046429931842
#  평균검증 정밀도   :  0.7738130582189183
#  평균검증 재현율   :  0.5672654577986579
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.7962788506829958
#  f1-score  :  0.6853401236813387
#  recall    :  0.6465339739190117
#  precision :  0.7291021671826625
#  ========= 2 =========
#  accuracy  :  0.7896844088553933
#  f1-score  :  0.6904679376083188
#  recall    :  0.6544021024967148
#  precision :  0.7307410124724871
#  ========= 3 =========
#  accuracy  :  0.8044758539458187
#  f1-score  :  0.7101955307262569
#  recall    :  0.6744031830238727
#  precision :  0.75
#  ========= 4 =========
#  accuracy  :  0.8035335689045936
#  f1-score  :  0.7036247334754798
#  recall    :  0.673469387755102
#  precision :  0.7366071428571429
#  ========= 5 =========
#  accuracy  :  0.7938751472320377
#  f1-score  :  0.6862674793832916
#  recall    :  0.6422818791946309
#  precision :  0.7367205542725174
#  ======== 최종 ========
#  평균검증 정확도   :  0.7975695659241677
#  평균검증 f1-score :  0.6951791609749371
#  평균검증 정밀도   :  0.6582181052778664
#  평균검증 재현율   :  0.736634175356962
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %%
# kor_ratio10_4gram
kor_r10_4g = total_model(kor_ratio10_4gram)
score_result = result_append(score_result, kor_r10_4g)
# Out:
# 64 번 인덱스 오류 처리 완료
# 91 번 인덱스 오류 처리 완료
# 104 번 인덱스 오류 처리 완료
# 116 번 인덱스 오류 처리 완료
# 130 번 인덱스 오류 처리 완료
# 131 번 인덱스 오류 처리 완료
# 132 번 인덱스 오류 처리 완료
# 134 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.8423067719550131
#  f1-score  :  0.7775902801214984
#  recall    :  0.7885010266940452
#  precision :  0.7669773635153129
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7293610911701364
#  f1-score  :  0.670933954029677
#  recall    :  0.7891854893908282
#  precision :  0.583502024291498
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8262742282842785
#  f1-score  :  0.742735648476258
#  recall    :  0.7173169062286106
#  precision :  0.7700220426157237
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.8427853553481695
#  f1-score  :  0.7753846153846154
#  recall    :  0.7985915492957747
#  precision :  0.7534883720930232
#  ========= 2 =========
#  accuracy  :  0.8403924383823881
#  f1-score  :  0.7828069032888311
#  recall    :  0.8072531900604433
#  precision :  0.7597977243994943
#  ========= 3 =========
#  accuracy  :  0.8393968405935854
#  f1-score  :  0.7786209171890466
#  recall    :  0.8038147138964578
#  precision :  0.7549584133077415
#  ========= 4 =========
#  accuracy  :  0.8451412158927717
#  f1-score  :  0.7841174507841174
#  recall    :  0.8004087193460491
#  precision :  0.7684761281883584
#  ========= 5 =========
#  accuracy  :  0.8475347056007659
#  f1-score  :  0.784869976359338
#  recall    :  0.7953456536618754
#  precision :  0.7746666666666666
#  ======== 최종 ========
#  평균검증 정확도   :  0.8430501111635362
#  평균검증 f1-score :  0.7811599726011896
#  평균검증 정밀도   :  0.8010827652521201
#  평균검증 재현율   :  0.7622774609310567
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7461115099306054
#  f1-score  :  0.6828101644245143
#  recall    :  0.8042253521126761
#  precision :  0.5932467532467532
#  ========= 2 =========
#  accuracy  :  0.7303182579564489
#  f1-score  :  0.6775393419170243
#  recall    :  0.7951645399597045
#  precision :  0.5902293120638086
#  ========= 3 =========
#  accuracy  :  0.718764959310675
#  f1-score  :  0.6639977123248499
#  recall    :  0.7908719346049047
#  precision :  0.5722030556924593
#  ========= 4 =========
#  accuracy  :  0.7486835806606031
#  f1-score  :  0.6898995865327822
#  recall    :  0.7956403269754768
#  precision :  0.6089676746611054
#  ========= 5 =========
#  accuracy  :  0.7307324078506462
#  f1-score  :  0.6703779665983006
#  recall    :  0.783025325119781
#  precision :  0.5860655737704918
#  ======== 최종 ========
#  평균검증 정확도   :  0.7349221431417957
#  평균검증 f1-score :  0.6769249543594943
#  평균검증 정밀도   :  0.7937854957545086
#  평균검증 재현율   :  0.5901424738869236
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8289064369466379
#  f1-score  :  0.742527907814188
#  recall    :  0.726056338028169
#  precision :  0.7597641857037583
#  ========= 2 =========
#  accuracy  :  0.8241206030150754
#  f1-score  :  0.7445255474452556
#  recall    :  0.7192746809939556
#  precision :  0.771613832853026
#  ========= 3 =========
#  accuracy  :  0.8152225945428435
#  f1-score  :  0.732871972318339
#  recall    :  0.7213896457765667
#  precision :  0.7447257383966245
#  ========= 4 =========
#  accuracy  :  0.8281474389660124
#  f1-score  :  0.7464689265536723
#  recall    :  0.7200272479564033
#  precision :  0.7749266862170088
#  ========= 5 =========
#  accuracy  :  0.8207276208712303
#  f1-score  :  0.7320214669051879
#  recall    :  0.7002053388090349
#  precision :  0.7668665667166417
#  ======== 최종 ========
#  평균검증 정확도   :  0.8234249388683599
#  평균검증 f1-score :  0.7396831642073285
#  평균검증 정밀도   :  0.717390650312826
#  평균검증 재현율   :  0.7635794019774119
# <ipython-input-48-56e53401fd57>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)

# %% [markdown]
# ### score 파일 저장

# %%
score_result
# Out:
#     logistic_Acc  logistic_F1  logistic_Rec  logistic_Pre  naivebayes_Acc  \
# 0       0.802690     0.718678      0.716074      0.721301        0.676096
# 1       0.838436     0.779279      0.812752      0.748455        0.710551
# 2       0.845418     0.782784      0.796715      0.769332        0.720268
# 3       0.923077     0.923923      0.921811      0.926045        0.751158
# 4       0.954813     0.955597      0.956481      0.954713        0.790539
# 5       0.972023     0.972644      0.975152      0.970149        0.813725
# 6       0.923077     0.923853      0.920896      0.926829        0.749305
# 7       0.953165     0.953903      0.953241      0.954567        0.784185
# 8       0.968197     0.968903      0.971402      0.966418        0.810856
# 9       0.799212     0.714380      0.713439      0.715324        0.688616
# 10      0.833255     0.771760      0.803356      0.742556        0.718323
# 11      0.839675     0.773342      0.782341      0.764548        0.728404
# 12      0.797821     0.714098      0.717391      0.710836        0.686297
# 13      0.833255     0.771465      0.802013      0.743159        0.716439
# 14      0.842307     0.777590      0.788501      0.766977        0.729361
#
#     naivebayes_F1  naivebayes_Rec  naivebayes_Pre  randomforest_Acc  \
# 0        0.619035        0.747694        0.528153          0.765129
# 1        0.652530        0.774497        0.563752          0.796514
# 2        0.659680        0.775496        0.573961          0.822446
# 3        0.746818        0.724280        0.770803          0.863531
# 4        0.792541        0.787037        0.798122          0.898564
# 5        0.814920        0.804032        0.826108          0.916786
# 6        0.746604        0.728852        0.765242          0.859129
# 7        0.787781        0.787963        0.787598          0.893857
# 8        0.813751        0.810127        0.817408          0.912960
# 9        0.631752        0.758893        0.541099          0.766752
# 10       0.662528        0.787919        0.571568          0.796514
# 11       0.668613        0.783710        0.582994          0.833214
# 12       0.629619        0.757576        0.538642          0.772316
# 13       0.659887        0.783893        0.569756          0.805228
# 14       0.670934        0.789185        0.583502          0.826274
#
#     logistic_F1  ...  logistic_5fold_Rec  logistic_5fold_Pre  \
# 0      0.624397  ...            0.732543            0.714478
# 1      0.691429  ...            0.781084            0.746030
# 2      0.730964  ...            0.808992            0.768530
# 3      0.865801  ...            0.923836            0.923268
# 4      0.900988  ...            0.953203            0.952394
# 5      0.919482  ...            0.972385            0.970658
# 6      0.861503  ...            0.922839            0.920756
# 7      0.896631  ...            0.953122            0.953771
# 8      0.915663  ...            0.969127            0.970931
# 9      0.633382  ...            0.733303            0.713690
# 10     0.700831  ...            0.778171            0.741526
# 11     0.753449  ...            0.806696            0.764841
# 12     0.644461  ...            0.726837            0.709698
# 13     0.712947  ...            0.773582            0.739563
# 14     0.742736  ...            0.801083            0.762277
#
#     naivebayes_5Fold_Acc  naivebayes_5Fold_F1  naivebayes_5Fold_Rec  \
# 0               0.677116             0.618273              0.743248
# 1               0.707684             0.648572              0.769117
# 2               0.731237             0.672366              0.788459
# 3               0.753383             0.751539              0.736221
# 4               0.791828             0.792048              0.780076
# 5               0.811498             0.812991              0.803568
# 6               0.750278             0.750443              0.741169
# 7               0.787497             0.789211              0.782777
# 8               0.807528             0.810124              0.805279
# 9               0.686622             0.627065              0.748799
# 10              0.716258             0.657668              0.777079
# 11              0.736549             0.678672              0.795267
# 12              0.685787             0.626215              0.748139
# 13              0.713620             0.654605              0.773813
# 14              0.734922             0.676925              0.793785
#
#     naivebayes_5Fold_Pre  randomforest_5Fold_Acc  randomforest_5Fold_F1  \
# 0               0.529307                0.770971               0.637507
# 1               0.560772                0.796957               0.689493
# 2               0.586130                0.825244               0.738567
# 3               0.767551                0.866311               0.868395
# 4               0.804419                0.894831               0.897044
# 5               0.822752                0.917683               0.919768
# 6               0.759997                0.863763               0.866321
# 7               0.795773                0.892336               0.894646
# 8               0.815089                0.915865               0.918117
# 9               0.539429                0.770137               0.643051
# 10              0.570109                0.798323               0.696505
# 11              0.591981                0.824095               0.741231
# 12              0.538512                0.767911               0.638267
# 13              0.567265                0.797570               0.695179
# 14              0.590142                0.823425               0.739683
#
#     randomforest_5Fold_Rec  randomforest_5Fold_Pre
# 0                 0.572475                0.719289
# 1                 0.642843                0.743520
# 2                 0.705796                0.774678
# 3                 0.870649                0.866235
# 4                 0.901727                0.892472
# 5                 0.925595                0.914058
# 6                 0.871358                0.861384
# 7                 0.899760                0.889607
# 8                 0.925211                0.911151
# 9                 0.588716                0.708571
# 10                0.659986                0.737489
# 11                0.720459                0.763385
# 12                0.581991                0.706656
# 13                0.658218                0.736634
# 14                0.717391                0.763579
#
# [15 rows x 24 columns]

# %%
# 나온 결과 저장
score_result.to_csv('result_final.csv')
